# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor

# %%
#data aquisition and loading

# %%
df = pd.read_csv('crop_yield_datasource.csv')

# %%
#Explore data

# %%
df.head()
# Out:
#    Year Location  Precipitation(mm)  Minimum Temperature (degree Celsius)  \
# 0  2008   Mysore         337.080500                             21.046833
# 1  2009   Mysore         386.173833                             20.970833
# 2  2010   Mysore         375.785167                             21.575333
# 3  2011   Mysore         457.364667                             21.226500
# 4  2012   Mysore         445.379833                                   NaN
#
#    Mean Temperature(degree Celsius)  Maximum Temperature(degree Celsius)  \
# 0                         24.516167                            28.030833
# 1                         24.446333                            27.958167
# 2                         25.042667                            28.557000
# 3                         24.695000                            28.208000
# 4                         25.219000                            28.733833
#
#    Reference Crop Evapotranspiration (mm)  Area (In Hectare)  \
# ...

# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
 
# Data
df1=pd.DataFrame({'x': range(1,11), 'y1': np.random.randn(10), 'y2': np.random.randn(10)+range(1,11), 'y3': np.random.randn(10)+range(11,21) })
 
# multiple line plot
plt.plot( 'x', 'y1', data=df1, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.plot( 'x', 'y2', data=df1, marker='', color='olive', linewidth=2)
plt.plot( 'x', 'y3', data=df1, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
plt.legend()
# Out:
# c:\python\lib\site-packages\matplotlib\pyplot.py:3261: RuntimeWarning: Second argument 'y1' is ambiguous: could be a color spec but is in data. Using as data.
# Either rename the entry in data or use three arguments to plot.
#   ret = ax.plot(*args, **kwargs)
# c:\python\lib\site-packages\matplotlib\pyplot.py:3261: RuntimeWarning: Second argument 'y2' is ambiguous: could be a color spec but is in data. Using as data.
# Either rename the entry in data or use three arguments to plot.
#   ret = ax.plot(*args, **kwargs)
# c:\python\lib\site-packages\matplotlib\pyplot.py:3261: RuntimeWarning: Second argument 'y3' is ambiguous: could be a color spec but is in data. Using as data.
# Either rename the entry in data or use three arguments to plot.
#   ret = ax.plot(*args, **kwargs)

# %%
df1.head()
# Out:
#    x        y1        y2         y3
# 0  1 -0.040107  0.636994  13.199822
# 1  2  1.767766  3.330974  10.695189
# 2  3 -0.028281  4.041333  13.054300
# 3  4  0.801292  5.130989  15.750286
# 4  5 -0.099315  5.936234  14.568516

# %%
plt.plot(df1['x'],df1['y1'],label='temp')
plt.plot(df1['x'], df1['y2'])
plt.plot(df1['x'],df1['y3'])
plt.legend()

# %%
df.tail()
# Out:
#     Year Location  Precipitation(mm)  Minimum Temperature (degree Celsius)  \
# 35  2013   Koppal         121.746167                             21.648000
# 36  2014   Koppal          95.321833                             21.051333
# 37  2015   Koppal         113.626667                             21.101833
# 38  2016   Koppal          84.365500                             21.347500
# 39  2017   Koppal          81.386667                             21.431000
#
#     Mean Temperature(degree Celsius)  Maximum Temperature(degree Celsius)  \
# 35                         25.897167                                  NaN
# 36                         25.286167                            29.576000
# 37                         25.343000                            29.633333
# 38                               NaN                            29.882667
# 39                         25.675500                            29.966667
#
#     Reference Crop Evapotranspiration (mm)  Area (In Hectare)  \
# ...

# %%
df.describe()
# Out:
#               Year  Precipitation(mm)  Minimum Temperature (degree Celsius)  \
# count    40.000000          38.000000                             38.000000
# mean   2012.500000         210.329048                             21.060136
# std       2.908872         135.474746                              0.895232
# min    2008.000000          61.475167                             19.339500
# 25%    2010.000000          96.070667                             20.377917
# 50%    2012.500000         161.092833                             21.272917
# 75%    2015.000000         315.139708                             21.672042
# max    2017.000000         541.423500                             22.462500
#
#        Mean Temperature(degree Celsius)  Maximum Temperature(degree Celsius)  \
# count                         37.000000                            38.000000
# mean                          25.138311                            29.224272
# ...

# %%
df.groupby('Location').describe()
# Out:
#          Area (In Hectare)                                                     \
#                      count     mean           std      min      25%       50%
# Location
# Koppal                10.0  38803.1   1632.419231  37081.0  37377.0   38360.0
# Mandya                10.0  59286.4   9326.559592  38327.0  56960.5   60879.0
# Mysore                10.0  97708.3  11621.419726  76564.0  93462.5  100291.5
# Raichur               10.0  87448.5  10649.875088  65710.0  81640.0   89921.0
#
#                               Maximum Temperature(degree Celsius)             \
#                 75%       max                               count       mean
# Location
# Koppal     40219.50   41650.0                                 9.0  29.853926
# Mandya     63830.75   72125.0                                10.0  27.615533
# Mysore    104900.00  110591.0                                10.0  28.313300
# Raichur    95778.25  100632.0                                 9.0  31.394296
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 10 columns):
# Year                                      40 non-null int64
# Location                                  40 non-null object
# Precipitation(mm)                         38 non-null float64
# Minimum Temperature (degree Celsius)      38 non-null float64
# Mean Temperature(degree Celsius)          37 non-null float64
# Maximum Temperature(degree Celsius)       38 non-null float64
# Reference Crop Evapotranspiration (mm)    37 non-null float64
# Area (In Hectare)                         40 non-null int64
# Production (In Tonnes)                    40 non-null int64
# Yield (Tonnes/Hect.)                      40 non-null float64
# dtypes: float64(6), int64(3), object(1)
# memory usage: 3.2+ KB

# %%
#check for missing values and handle them

print("*****Number of Missing Data present in dataset*****\n")
print(df.isnull().sum())
print("\n")
print("*****Handling Missing Data present in dataset*****\n")
print("*****Performing Mean imputation*****\n")
df_preprocessed_data = df.fillna(value=df.mean())
print(df_preprocessed_data.head())
# Out:
# *****Number of Missing Data present in dataset*****
#
# Year                                      0
# Location                                  0
# Precipitation(mm)                         2
# Minimum Temperature (degree Celsius)      2
# Mean Temperature(degree Celsius)          3
# Maximum Temperature(degree Celsius)       2
# Reference Crop Evapotranspiration (mm)    3
# Area (In Hectare)                         0
# Production (In Tonnes)                    0
# Yield (Tonnes/Hect.)                      0
# dtype: int64
#
#
# *****Handling Missing Data present in dataset*****
#
# *****Performing Mean imputation*****
#
#    Year Location  Precipitation(mm)  Minimum Temperature (degree Celsius)  \
# 0  2008   Mysore         337.080500                             21.046833
# 1  2009   Mysore         386.173833                             20.970833
# 2  2010   Mysore         375.785167                             21.575333
# ...

# %%
#convert categorical values to continous

df_preprocessed_data["Location"] = df_preprocessed_data["Location"].replace(["Mysore", "Mandya", "Raichur", "Koppal"], [1,2,3,4])
print("\n*****Handling Categorical Data*****\n")
print(df_preprocessed_data.head())
# Out:
# *****Handling Categorical Data*****
#
#    Year  Location  Precipitation(mm)  Minimum Temperature (degree Celsius)  \
# 0  2008         1         337.080500                             21.046833
# 1  2009         1         386.173833                             20.970833
# 2  2010         1         375.785167                             21.575333
# 3  2011         1         457.364667                             21.226500
# 4  2012         1         445.379833                             21.060136
#
#    Mean Temperature(degree Celsius)  Maximum Temperature(degree Celsius)  \
# 0                         24.516167                            28.030833
# 1                         24.446333                            27.958167
# 2                         25.042667                            28.557000
# 3                         24.695000                            28.208000
# 4                         25.219000                            28.733833
#
# ...

# %%
#perform data transformation by doing Normalization

feature_cols = list(df_preprocessed_data)
predict_cols = feature_cols[-1:]
df_target = df_preprocessed_data[predict_cols]
df_input_data = df_preprocessed_data.iloc[:,1:9]
print(df_target.head())
print(df_input_data.head())
# Out:
#    Yield (Tonnes/Hect.)
# 0              3.009976
# 1              3.203097
# 2              2.713547
# 3              2.986351
# 4              3.141604
#    Location  Precipitation(mm)  Minimum Temperature (degree Celsius)  \
# 0         1         337.080500                             21.046833
# 1         1         386.173833                             20.970833
# 2         1         375.785167                             21.575333
# 3         1         457.364667                             21.226500
# 4         1         445.379833                             21.060136
#
#    Mean Temperature(degree Celsius)  Maximum Temperature(degree Celsius)  \
# 0                         24.516167                            28.030833
# 1                         24.446333                            27.958167
# 2                         25.042667                            28.557000
# 3                         24.695000                            28.208000
# ...

# %%
df_input_data = (df_input_data - df_input_data.mean()) / (df_input_data.max() - df_input_data.min())
print("\n*****Normalized Data*****\n")
print(df_input_data.head())
# Out:
# *****Normalized Data*****
#
#    Location  Precipitation(mm)  Minimum Temperature (degree Celsius)  \
# 0      -0.5           0.264094                         -4.259569e-03
# 1      -0.5           0.366383                         -2.859514e-02
# 2      -0.5           0.344737                          1.649687e-01
# 3      -0.5           0.514713                          5.327058e-02
# 4      -0.5           0.489742                          1.137596e-15
#
#    Mean Temperature(degree Celsius)  Maximum Temperature(degree Celsius)  \
# 0                         -0.161122                            -0.256580
# 1                         -0.179207                            -0.272203
# 2                         -0.024770                            -0.143458
# 3                         -0.114808                            -0.218490
# 4                          0.020897                            -0.105440
#
#    Reference Crop Evapotranspiration (mm)  Area (In Hectare)  \
# ...

# %%
df_preprocessed_data = df_input_data.join(df_target)
print(df_preprocessed_data.head())

preprocessedfile = 'crop_yield_datasource_preprocessed.csv'
df_preprocessed_data.to_csv(preprocessedfile, index=False)
# Out:
#    Location  Precipitation(mm)  Minimum Temperature (degree Celsius)  \
# 0      -0.5           0.264094                         -4.259569e-03
# 1      -0.5           0.366383                         -2.859514e-02
# 2      -0.5           0.344737                          1.649687e-01
# 3      -0.5           0.514713                          5.327058e-02
# 4      -0.5           0.489742                          1.137596e-15
#
#    Mean Temperature(degree Celsius)  Maximum Temperature(degree Celsius)  \
# 0                         -0.161122                            -0.256580
# 1                         -0.179207                            -0.272203
# 2                         -0.024770                            -0.143458
# 3                         -0.114808                            -0.218490
# 4                          0.020897                            -0.105440
#
#    Reference Crop Evapotranspiration (mm)  Area (In Hectare)  \
# ...

# %%
df.head()
# Out:
#    Year Location  Precipitation(mm)  Minimum Temperature (degree Celsius)  \
# 0  2008   Mysore         337.080500                             21.046833
# 1  2009   Mysore         386.173833                             20.970833
# 2  2010   Mysore         375.785167                             21.575333
# 3  2011   Mysore         457.364667                             21.226500
# 4  2012   Mysore         445.379833                                   NaN
#
#    Mean Temperature(degree Celsius)  Maximum Temperature(degree Celsius)  \
# 0                         24.516167                            28.030833
# 1                         24.446333                            27.958167
# 2                         25.042667                            28.557000
# 3                         24.695000                            28.208000
# 4                         25.219000                            28.733833
#
#    Reference Crop Evapotranspiration (mm)  Area (In Hectare)  \
# ...

# %%
df_preprocessed_data.head()
# Out:
#    Location  Precipitation(mm)  Minimum Temperature (degree Celsius)  \
# 0      -0.5           0.264094                         -4.259569e-03
# 1      -0.5           0.366383                         -2.859514e-02
# 2      -0.5           0.344737                          1.649687e-01
# 3      -0.5           0.514713                          5.327058e-02
# 4      -0.5           0.489742                          1.137596e-15
#
#    Mean Temperature(degree Celsius)  Maximum Temperature(degree Celsius)  \
# 0                         -0.161122                            -0.256580
# 1                         -0.179207                            -0.272203
# 2                         -0.024770                            -0.143458
# 3                         -0.114808                            -0.218490
# 4                          0.020897                            -0.105440
#
#    Reference Crop Evapotranspiration (mm)  Area (In Hectare)  \
# ...

# %%
#Spliting dataa into train and test data

# %%
feature_cols = list(df_preprocessed_data)
predict_cols = feature_cols[-1:]
y = df_preprocessed_data[predict_cols]
X = df_preprocessed_data.iloc[:,:8]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
#Building Decision tree regression model and testing it

# %%
DT_regressor = DecisionTreeRegressor()
DT_regressor.fit(X_train, y_train)

dt_pred = DT_regressor.predict(X_test)

print('\n *****Decision Tree Regression Results*****')
print('\n prediction of decision tree regression model for test data: ',dt_pred)

# The mean squared error
print('\n Mean squared error of decision tree regression: %.2f ' % np.mean((DT_regressor.predict(X_test.values) - y_test.values) ** 2))
# Explained coefficient of determination score: 1 is perfect prediction
print('\n Coeff. determination score of decision tree  regression: %.2f' % DT_regressor.score(X_test.values, y_test.values))

df_preprocessed_data['DT_Prediction']=DT_regressor.predict(X)
# Out:
#  *****Decision Tree Regression Results*****
#
#  prediction of decision tree regression model for test data:  [3.15045294 2.62034709 2.62034709 3.20309676 3.01623062 2.98635129
#  2.62034709 3.01623062]
#
#  Mean squared error of decision tree regression: 0.16
#
#  Coeff. determination score of decision tree  regression: -1.79

# %%
df_preprocessed_data.head(50)
# Out:
#     Location  Precipitation(mm)  Minimum Temperature (degree Celsius)  \
# 0  -0.500000           0.264094                         -4.259569e-03
# 1  -0.500000           0.366383                         -2.859514e-02
# 2  -0.500000           0.344737                          1.649687e-01
# 3  -0.500000           0.514713                          5.327058e-02
# 4  -0.500000           0.489742                          1.137596e-15
# 5  -0.500000           0.689854                          1.282519e-01
# 6  -0.500000           0.237718                          5.764672e-02
# 7  -0.500000           0.367843                         -6.927943e-03
# 8  -0.500000           0.201113                          7.862014e-02
# 9  -0.500000           0.224134                          1.958151e-01
# 10 -0.166667           0.087071                         -5.195760e-01
# 11 -0.166667           0.025864                         -5.509561e-01
# ...

# %%
#Building Multiple linear regression model and testing it

# %%
linear_regressor = LinearRegression()
linear_regressor.fit(X_train, y_train)

mlr_pred = linear_regressor.predict(X_test)

print('\n *****Multiple Linear Regression Results*****')
print('\n prediction of multiple linear regression model for test data: ',mlr_pred)

# The coefficients and intercept:
print('\n Coefficients of multiple linear regression: ',linear_regressor.coef_)
print('\n Intercept of multiple linear regression: ',linear_regressor.intercept_)

# The mean squared error
print('\n Mean squared error of multiple linear regression: %.2f ' % np.mean((linear_regressor.predict(X_test) - y_test) ** 2))
# Explained coefficient of determination score: 1 is perfect prediction
print('\n Coeff. determination score of multiple linear regression: %.2f' % linear_regressor.score(X_test, y_test))

df_preprocessed_data['MLR_Prediction']=linear_regressor.predict(X)
# Out:
#  *****Multiple Linear Regression Results*****
#
#  prediction of multiple linear regression model for test data:  [[3.56103864]
#  [3.19020551]
#  [2.62470345]
#  [3.26621238]
#  [2.9472919 ]
#  [3.11578352]
#  [3.75514815]
#  [3.06993319]]
#
#  Coefficients of multiple linear regression:  [[ 0.6038881   0.3837518   0.01186722 -0.25098682  0.34863023 -0.29497679
#   -3.1127382   3.35353092]]
#
#  Intercept of multiple linear regression:  [3.18687408]
#
#  Mean squared error of multiple linear regression: 0.02
#
#  Coeff. determination score of multiple linear regression: 0.66

# %%
df_preprocessed_data.head(50)
# Out:
#     Location  Precipitation(mm)  Minimum Temperature (degree Celsius)  \
# 0  -0.500000           0.264094                         -4.259569e-03
# 1  -0.500000           0.366383                         -2.859514e-02
# 2  -0.500000           0.344737                          1.649687e-01
# 3  -0.500000           0.514713                          5.327058e-02
# 4  -0.500000           0.489742                          1.137596e-15
# 5  -0.500000           0.689854                          1.282519e-01
# 6  -0.500000           0.237718                          5.764672e-02
# 7  -0.500000           0.367843                         -6.927943e-03
# 8  -0.500000           0.201113                          7.862014e-02
# 9  -0.500000           0.224134                          1.958151e-01
# 10 -0.166667           0.087071                         -5.195760e-01
# 11 -0.166667           0.025864                         -5.509561e-01
# ...

# %%
# save result in file
filename = 'Crop_yield_predicted_output.csv'
df_preprocessed_data.to_csv(filename, index=False, encoding='utf-8')

# %%
new_data=pd.read_csv('New_crop_data.csv')

# %%
new_data
# Out:
#     Year Location  Precipitation(mm)  Minimum Temperature (degree Celsius)  \
# 0   2018   Mysore         337.080500                             21.046833
# 1   2019   Mysore         445.379833                             20.080310
# 2   2020   Mysore         324.421333                             21.240167
# 3   2018   Mandya         282.824333                             20.207833
# 4   2019   Mandya         392.419333                             19.898500
# 5   2020   Mandya         262.536667                             19.955333
# 6   2018  Raichur          98.317167                             22.357667
# 7   2019  Raichur          66.054500                             21.619000
# 8   2020  Raichur          93.076000                             21.683833
# 9   2018   Koppal         105.302667                             21.801667
# 10  2019   Koppal          81.386667                             21.431000
# ...

# %%
new_data_processed=new_data.iloc[:,1:9]
new_data_processed["Location"] = new_data_processed["Location"].replace(["Mysore", "Mandya", "Raichur", "Koppal"], [1,2,3,4])

# %%
new_data_processed
# Out:
#     Location  Precipitation(mm)  Minimum Temperature (degree Celsius)  \
# 0          1         337.080500                             21.046833
# 1          1         445.379833                             20.080310
# 2          1         324.421333                             21.240167
# 3          2         282.824333                             20.207833
# 4          2         392.419333                             19.898500
# 5          2         262.536667                             19.955333
# 6          3          98.317167                             22.357667
# 7          3          66.054500                             21.619000
# 8          3          93.076000                             21.683833
# 9          4         105.302667                             21.801667
# 10         4          81.386667                             21.431000
# 11         4         113.626667                             21.101833
#
# ...

# %%
new_data_processed = (new_data_processed - new_data_processed.mean()) / (new_data_processed.max() - new_data_processed.min())

# %%
new_data_processed
# Out:
#     Location  Precipitation(mm)  Minimum Temperature (degree Celsius)  \
# 0  -0.500000           0.316909                              0.004677
# 1  -0.500000           0.602414                             -0.388352
# 2  -0.500000           0.283536                              0.083295
# 3  -0.166667           0.173876                             -0.336495
# 4  -0.166667           0.462797                             -0.462283
# 5  -0.166667           0.120392                             -0.439172
# 6   0.166667          -0.312533                              0.537717
# 7   0.166667          -0.397586                              0.237344
# 8   0.166667          -0.326350                              0.263708
# 9   0.500000          -0.294117                              0.311624
# 10  0.500000          -0.357166                              0.160895
# 11  0.500000          -0.272173                              0.027042
#
# ...

# %%
print("crop yield prediction using Decision Tree model\n")
new_data['yield prediction from DT']=DT_regressor.predict(new_data_processed)
new_data.head(15)
# Out:
# crop yield prediction using Decision Tree model
#     Year Location  Precipitation(mm)  Minimum Temperature (degree Celsius)  \
# 0   2018   Mysore         337.080500                             21.046833
# 1   2019   Mysore         445.379833                             20.080310
# 2   2020   Mysore         324.421333                             21.240167
# 3   2018   Mandya         282.824333                             20.207833
# 4   2019   Mandya         392.419333                             19.898500
# 5   2020   Mandya         262.536667                             19.955333
# 6   2018  Raichur          98.317167                             22.357667
# 7   2019  Raichur          66.054500                             21.619000
# 8   2020  Raichur          93.076000                             21.683833
# 9   2018   Koppal         105.302667                             21.801667
# 10  2019   Koppal          81.386667                             21.431000
# ...

# %%
print("crop yield prediction using Multiple Linear Regression Model\n")
new_data['yield prediction from MLR']=linear_regressor.predict(new_data_processed)
new_data.head(15)
# Out:
# crop yield prediction using Multiple Linear Regression Model
#     Year Location  Precipitation(mm)  Minimum Temperature (degree Celsius)  \
# 0   2018   Mysore         337.080500                             21.046833
# 1   2019   Mysore         445.379833                             20.080310
# 2   2020   Mysore         324.421333                             21.240167
# 3   2018   Mandya         282.824333                             20.207833
# 4   2019   Mandya         392.419333                             19.898500
# 5   2020   Mandya         262.536667                             19.955333
# 6   2018  Raichur          98.317167                             22.357667
# 7   2019  Raichur          66.054500                             21.619000
# 8   2020  Raichur          93.076000                             21.683833
# 9   2018   Koppal         105.302667                             21.801667
# 10  2019   Koppal          81.386667                             21.431000
# ...

# %%
# save result in file
filename = 'Crop_yield_predictionfornewdata.csv'
new_data.to_csv(filename, index=False, encoding='utf-8')
